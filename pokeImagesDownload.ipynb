# %%
from google_images_download import google_images_download

# %%
import numpy as np
import pandas as pd

# %%
poke = pd.read_csv('pokemon.csv')
poke['Type 2'].fillna(poke['Type 1'], inplace = True) #for every Pokemon with no Type 2, Type 2 is set to be the same with Type 1
poke.set_index('#', inplace = True) #without this, #800 would be lost
poke['Name'].fillna('Primeape', inplace = True)
pokeList = list(poke['Name'].values)
pokeList2 = [pokemon + ' smogon' for pokemon in pokeList]
pokeList2
pokeDownloadNames = ','.join(pokeList2) 
pokeDownloadNames
# Out:
# "Bulbasaur smogon,Ivysaur smogon,Venusaur smogon,Mega Venusaur smogon,Charmander smogon,Charmeleon smogon,Charizard smogon,Mega Charizard X smogon,Mega Charizard Y smogon,Squirtle smogon,Wartortle smogon,Blastoise smogon,Mega Blastoise smogon,Caterpie smogon,Metapod smogon,Butterfree smogon,Weedle smogon,Kakuna smogon,Beedrill smogon,Mega Beedrill smogon,Pidgey smogon,Pidgeotto smogon,Pidgeot smogon,Mega Pidgeot smogon,Rattata smogon,Raticate smogon,Spearow smogon,Fearow smogon,Ekans smogon,Arbok smogon,Pikachu smogon,Raichu smogon,Sandshrew smogon,Sandslash smogon,Nidoran♀ smogon,Nidorina smogon,Nidoqueen smogon,Nidoran♂ smogon,Nidorino smogon,Nidoking smogon,Clefairy smogon,Clefable smogon,Vulpix smogon,Ninetales smogon,Jigglypuff smogon,Wigglytuff smogon,Zubat smogon,Golbat smogon,Oddish smogon,Gloom smogon,Vileplume smogon,Paras smogon,Parasect smogon,Venonat smogon,Venomoth smogon,Diglett smogon,Dugtrio smogon,Meowth smogon,Persian smogon,Psyduck smogon,Golduck smogon,Mankey smo
# ...

# %%
response = google_images_download.googleimagesdownload()

# %%
arguments = {'keywords':pokeDownloadNames, 'limit':1}

# %%
paths = response.download(arguments)
# Out:
# Item no.: 1 --> Item name = Bulbasaur smogon
# Evaluating...
# Starting Download...
# Completed Image ====> 1. proxy.php
#
# Errors: 0
#
#
# Item no.: 2 --> Item name = Ivysaur smogon
# Evaluating...
# Starting Download...
# Completed Image ====> 1. .jpg
#
# Errors: 0
#
#
# Item no.: 3 --> Item name = Venusaur smogon
# Evaluating...
# Starting Download...
# Completed Image ====> 1. .jpg
#
# Errors: 0
#
#
# Item no.: 4 --> Item name = Mega Venusaur smogon
# Evaluating...
# Starting Download...
# Completed Image ====> 1. .jpg
#
# Errors: 0
#
#
# Item no.: 5 --> Item name = Charmander smogon
# Evaluating...
# Starting Download...
# Completed Image ====> 1. proxy.php
#
# Errors: 0
#
#
# Item no.: 6 --> Item name = Charmeleon smogon
# Evaluating...
# Starting Download...
# Completed Image ====> 1. latest?cb=20160626215620.jpg
#
# Errors: 0
#
#
# Item no.: 7 --> Item name = Charizard smogon
# Evaluating...
# Starting Download...
# Completed Image ====> 1. charizard-mega-y.gif
#
# ...

# %%
poke.head()
# Out:
#             Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# #
# 1      Bulbasaur  Grass  Poison  45      49       49       65       65     45
# 2        Ivysaur  Grass  Poison  60      62       63       80       80     60
# 3       Venusaur  Grass  Poison  80      82       83      100      100     80
# 4  Mega Venusaur  Grass  Poison  80     100      123      122      120     80
# 5     Charmander   Fire    Fire  39      52       43       60       50     65
#
#    Generation  Legendary
# #
# 1           1      False
# 2           1      False
# 3           1      False
# 4           1      False
# 5           1      False

# %%
poke.tail()
# Out:
#                Name   Type 1 Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# #
# 796         Diancie     Rock  Fairy  50     100      150      100      150
# 797    Mega Diancie     Rock  Fairy  50     160      110      160      110
# 798  Hoopa Confined  Psychic  Ghost  80     110       60      150      130
# 799   Hoopa Unbound  Psychic   Dark  80     160       60      170      130
# 800       Volcanion     Fire  Water  80     110      120      130       90
#
#      Speed  Generation  Legendary
# #
# 796     50           6       True
# 797    110           6       True
# 798     70           6       True
# 799     80           6       True
# 800     70           6       True
