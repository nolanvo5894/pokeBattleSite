# %%
import os
path = os.getcwd()
path
pics = os.listdir(path)

# %%
picNames = [pic.split('.')[0] for pic in pics]
len(picNames)
# Out:
# 853

# %%
import pandas as pd
poke = pd.read_csv('../../pokemon.csv')
pokeNames = list(poke['Name'])
pokeNames
# Out:
# ['Bulbasaur',
#  'Ivysaur',
#  'Venusaur',
#  'Mega Venusaur',
#  'Charmander',
#  'Charmeleon',
#  'Charizard',
#  'Mega Charizard X',
#  'Mega Charizard Y',
#  'Squirtle',
#  'Wartortle',
#  'Blastoise',
#  'Mega Blastoise',
#  'Caterpie',
#  'Metapod',
#  'Butterfree',
#  'Weedle',
#  'Kakuna',
#  'Beedrill',
#  'Mega Beedrill',
#  'Pidgey',
#  'Pidgeotto',
#  'Pidgeot',
#  'Mega Pidgeot',
#  'Rattata',
#  'Raticate',
#  'Spearow',
#  'Fearow',
#  'Ekans',
#  'Arbok',
#  'Pikachu',
#  'Raichu',
#  'Sandshrew',
#  'Sandslash',
#  'Nidoran♀',
#  'Nidorina',
#  'Nidoqueen',
#  'Nidoran♂',
#  'Nidorino',
#  'Nidoking',
#  'Clefairy',
#  'Clefable',
#  'Vulpix',
#  'Ninetales',
#  'Jigglypuff',
#  'Wigglytuff',
#  'Zubat',
#  'Golbat',
#  'Oddish',
#  'Gloom',
#  'Vileplume',
#  'Paras',
#  'Parasect',
#  'Venonat',
#  'Venomoth',
#  'Diglett',
#  'Dugtrio',
#  'Meowth',
#  'Persian',
#  'Psyduck',
#  'Golduck',
#  'Mankey',
#  'Primeape',
#  'Growlithe',
#  'Arcanine',
#  'Poliwag',
# ...

# %%
for poke in pokeNames:
    if poke not in picNames:
        print(poke)

# %%
picFolders = [pic for pic in pics if os.path.isdir(pic)]
picFolders
# Out:
# ['Sawsbuck',
#  'Cherrim',
#  'Burmy',
#  'Basculin',
#  'Furfrou',
#  'Deerling',
#  'Zygarde',
#  'Gastrodon',
#  '.ipynb_checkpoints',
#  'Pyroar',
#  'Shellos']
