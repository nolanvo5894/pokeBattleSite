# %%
from google_images_download import google_images_download

# %%
import numpy as np
import pandas as pd

# %%
poke = pd.read_csv('pokemon.csv')
poke['Type 2'].fillna(poke['Type 1'], inplace = True) #for every Pokemon with no Type 2, Type 2 is set to be the same with Type 1
poke.set_index('#', inplace = True) #without this, #800 would be lost
poke['Name'].fillna('Primeape', inplace = True)
pokeList = list(poke['Name'].values)
pokeList2 = [pokemon + ' site: https://bulbahandbook.bulbagarden.net/' for pokemon in pokeList]
pokeList2
pokeDownloadNames = ','.join(pokeList2) 
pokeDownloadNames
# Out:
# "Bulbasaur veekun,Ivysaur veekun,Venusaur veekun,Mega Venusaur veekun,Charmander veekun,Charmeleon veekun,Charizard veekun,Mega Charizard X veekun,Mega Charizard Y veekun,Squirtle veekun,Wartortle veekun,Blastoise veekun,Mega Blastoise veekun,Caterpie veekun,Metapod veekun,Butterfree veekun,Weedle veekun,Kakuna veekun,Beedrill veekun,Mega Beedrill veekun,Pidgey veekun,Pidgeotto veekun,Pidgeot veekun,Mega Pidgeot veekun,Rattata veekun,Raticate veekun,Spearow veekun,Fearow veekun,Ekans veekun,Arbok veekun,Pikachu veekun,Raichu veekun,Sandshrew veekun,Sandslash veekun,Nidoran♀ veekun,Nidorina veekun,Nidoqueen veekun,Nidoran♂ veekun,Nidorino veekun,Nidoking veekun,Clefairy veekun,Clefable veekun,Vulpix veekun,Ninetales veekun,Jigglypuff veekun,Wigglytuff veekun,Zubat veekun,Golbat veekun,Oddish veekun,Gloom veekun,Vileplume veekun,Paras veekun,Parasect veekun,Venonat veekun,Venomoth veekun,Diglett veekun,Dugtrio veekun,Meowth veekun,Persian veekun,Psyduck veekun,Golduck veekun,Mankey veekun,Primeape veekun,Growlithe veekun,Arcanine veekun,Poliwag veekun,Poliwhirl veekun,Poliwrath veekun,Abra veekun,Kadabra veekun,Alakazam veekun,Mega Alakazam veekun,Machop veekun,Machoke veekun,Machamp veekun,Bellsprout veekun,Weepinbell veekun,Victreebel veekun,Tentacool veekun,Tentacruel veekun,Geodude veekun,Graveler veekun,Golem veekun,Ponyta veekun,Rapidash veekun,Slowpoke veekun,Slowbro veekun,Mega Slowbro veekun,Magnemite veekun,Magneton veekun,Farfetch'd veekun,Doduo veekun,Dodrio veekun,Seel veekun,Dewgong veekun,Grimer veekun,Muk veekun,Shellder veekun,Cloyster veekun,Gastly veekun,Haunter veekun,Gengar veekun,Mega Gengar veekun,Onix veekun,Drowzee veekun,Hypno veekun,Krabby veekun,Kingler veekun,Voltorb veekun,Electrode veekun,Exeggcute veekun,Exeggutor veekun,Cubone veekun,Marowak veekun,Hitmonlee veekun,Hitmonchan veekun,Lickitung veekun,Koffing veekun,Weezing veekun,Rhyhorn veekun,Rhydon veekun,Chansey veekun,Tangela veekun,Kangaskhan veekun,Mega Kangaskhan veekun,Horsea veekun,Seadra veekun,Goldeen veekun,Seaking veekun,Staryu veekun,Starmie veekun,Mr. Mime veekun,Scyther veekun,Jynx veekun,Electabuzz veekun,Magmar veekun,Pinsir veekun,Mega Pinsir veekun,Tauros veekun,Magikarp veekun,Gyarados veekun,Mega Gyarados veekun,Lapras veekun,Ditto veekun,Eevee veekun,Vaporeon veekun,Jolteon veekun,Flareon veekun,Porygon veekun,Omanyte veekun,Omastar veekun,Kabuto veekun,Kabutops veekun,Aerodactyl veekun,Mega Aerodactyl veekun,Snorlax veekun,Articuno veekun,Zapdos veekun,Moltres veekun,Dratini veekun,Dragonair veekun,Dragonite veekun,Mewtwo veekun,Mega Mewtwo X veekun,Mega Mewtwo Y veekun,Mew veekun,Chikorita veekun,Bayleef veekun,Meganium veekun,Cyndaquil veekun,Quilava veekun,Typhlosion veekun,Totodile veekun,Croconaw veekun,Feraligatr veekun,Sentret veekun,Furret veekun,Hoothoot veekun,Noctowl veekun,Ledyba veekun,Ledian veekun,Spinarak veekun,Ariados veekun,Crobat veekun,Chinchou veekun,Lanturn veekun,Pichu veekun,Cleffa veekun,Igglybuff veekun,Togepi veekun,Togetic veekun,Natu veekun,Xatu veekun,Mareep veekun,Flaaffy veekun,Ampharos veekun,Mega Ampharos veekun,Bellossom veekun,Marill veekun,Azumarill veekun,Sudowoodo veekun,Politoed veekun,Hoppip veekun,Skiploom veekun,Jumpluff veekun,Aipom veekun,Sunkern veekun,Sunflora veekun,Yanma veekun,Wooper veekun,Quagsire veekun,Espeon veekun,Umbreon veekun,Murkrow veekun,Slowking veekun,Misdreavus veekun,Unown veekun,Wobbuffet veekun,Girafarig veekun,Pineco veekun,Forretress veekun,Dunsparce veekun,Gligar veekun,Steelix veekun,Mega Steelix veekun,Snubbull veekun,Granbull veekun,Qwilfish veekun,Scizor veekun,Mega Scizor veekun,Shuckle veekun,Heracross veekun,Mega Heracross veekun,Sneasel veekun,Teddiursa veekun,Ursaring veekun,Slugma veekun,Magcargo veekun,Swinub veekun,Piloswine veekun,Corsola veekun,Remoraid veekun,Octillery veekun,Delibird veekun,Mantine veekun,Skarmory veekun,Houndour veekun,Houndoom veekun,Mega Houndoom veekun,Kingdra veekun,Phanpy veekun,Donphan veekun,Porygon2 veekun,Stan ...

# %%
response = google_images_download.googleimagesdownload()

# %%
arguments = {'keywords':pokeDownloadNames, 'limit':1}

# %%
paths = response.download(arguments)
# Out:
# Item no.: 1 --> Item name = Bulbasaur veekun
# Evaluating...
# Starting Download...
# Completed Image ====> 1. 1.svg
#
# Errors: 0
#
#
# Item no.: 2 --> Item name = Ivysaur veekun
# Evaluating...
# Starting Download...
# Completed Image ====> 1. 2.png
#
# Errors: 0
#
#
# Item no.: 3 --> Item name = Venusaur veekun
# Evaluating...
# Starting Download...
# Completed Image ====> 1. 3-mega.png
#
# Errors: 0
#
#
# Item no.: 4 --> Item name = Mega Venusaur veekun
# Evaluating...
# Starting Download...
# Completed Image ====> 1. 3-mega.png
#
# Errors: 0
#
#
# Item no.: 5 --> Item name = Charmander veekun
# Evaluating...
# Starting Download...
# Completed Image ====> 1. 8a231f59cdaa78660bc5feb94e6cd807.png
#
# Errors: 0
#
#
# Item no.: 6 --> Item name = Charmeleon veekun
# Evaluating...
# Starting Download...
# Completed Image ====> 1. 5.png
#
# Errors: 0
#
#
# Item no.: 7 --> Item name = Charizard veekun
# Evaluating...
# Starting Download...
# Completed Image ====> 1. 6-mega-y.png
#
# Errors: 0
#
#
# Item no.: 8 --> Item name = Mega Charizard X veekun
# Evaluating...
# Starting Download...
# Completed Image ====> 1. 6-mega-x.png
#
# Errors: 0
#
#
# Item no.: 9 --> Item name = Mega Charizard Y veekun
# Evaluating...
# Starting Download...
# Completed Image ====> 1. 6-mega-y.png
#
# Errors: 0
#
#
# Item no.: 10 --> Item name = Squirtle veekun
# Evaluating...
# Starting Download...
# Completed Image ====> 1. large.sugimori.png
#
# Errors: 0
#
#
# Item no.: 11 --> Item name = Wartortle veekun
# Evaluating...
# Starting Download...
# Completed Image ====> 1. 8.png
#
# Errors: 0
#
#
# Item no.: 12 --> Item name = Blastoise veekun
# Evaluating...
# Starting Download...
# Completed Image ====> 1. 9-mega.png
#
# Errors: 0
#
#
# Item no.: 13 --> Item name = Mega Blastoise veekun
# Evaluating...
# Starting Download...
# Completed Image ====> 1. 9-mega.png
#
# Errors: 0
#
#
# Item no.: 14 --> Item name = Caterpie veekun
# Evaluating...
# Starting Download...
# Completed Image ====> 1. 10.png
#
# Errors: 0
#
#
# Item no.: 15 --> Item name = Metapod veekun
# Evaluating...
# Starting Download...
# Completed Image ====> 1. 11.png
#
# Errors: 0
#
#
# Item no.: 16 --> Item name = Butterfree veekun
# Evaluating...
# Starting Download...
# Completed Image ====> 1. 12.png
#
# Errors: 0
#
#
# Item no.: 17 --> Item name = Weedle veekun
# Evaluating...
# Starting Download...
# Completed Image ====> 1. 13.png
#
# Errors: 0
#
#
# Item no.: 18 --> Item name = Kakuna veekun
# Evaluating...
# Starting Download...
# Completed Image ====> 1. 783e49e1fecedf3db1daf21238f0b5cd--pokemon-pokedex--pokemon.jpg
#
# Errors: 0
#
#
# Item no.: 19 --> Item name = Beedrill veekun
# Evaluating...
# Starting Download...
# Completed Image ====> 1. 15-mega.png
#
# Errors: 0
#
#
# Item no.: 20 --> Item name = Mega Beedrill veekun
# Evaluating...
# Starting Download...
# Completed Image ====> 1. 15-mega.png
#
# Errors: 0
#
#
# Item no.: 21 --> Item name = Pidgey veekun
# Evaluating...
# Starting Download...
# Completed Image ====> 1. 16.png
#
# Errors: 0
#
#
# Item no.: 22 --> Item name = Pidgeotto veekun
# Evaluating...
# Starting Download...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-bad4114a4c4d> in <module>()
# ----> 1 paths = response.download(arguments)
#
# ~/anaconda3/lib/python3.6/site-packages/google_images_download/google_images_download.py in download(self, arguments)
#     841
#     842                     print("Starting Download...")
# --> 843                     items,errorCount,abs_path = self._get_all_items(raw_html,main_directory,dir_name,limit,arguments)    #get all image items and download images
#     844                     paths[pky + search_keyword[i] + sky] = abs_path
#     845
#
# ~/anaconda3/lib/python3.6/site-packages/google_images_download/google_images_download.py in _get_all_items(self, page, main_directory, dir_name, limit, arguments)
#     707
#     708                 #download the images
# --> 709                 download_status,download_message,return_image_name,absolute_path = self.download_image(object['image_link'],object['image_format'],main_directory,dir_name,count,arguments['print_urls'],arguments['socket_timeout'],arguments['prefix'],arguments['print_size'],arguments['no_numbering'])
#     710                 print(download_message)
#     711                 if download_status == "success":
#
# ~/anaconda3/lib/python3.6/site-packages/google_images_download/google_images_download.py in download_image(self, image_url, image_format, main_directory, dir_name, count, print_urls, socket_timeout, prefix, print_size, no_numbering)
#     565
#     566                 response = urlopen(req, None, timeout)
# --> 567                 data = response.read()
#     568                 response.close()
#     569
#
# ~/anaconda3/lib/python3.6/http/client.py in read(self, amt)
#     460             else:
#     461                 try:
# --> 462                     s = self._safe_read(self.length)
#     463                 except IncompleteRead:
#     464                     self._close_conn()
#
# ~/anaconda3/lib/python3.6/http/client.py in _safe_read(self, amt)
#     610         s = []
#     611         while amt > 0:
# --> 612             chunk = self.fp.read(min(amt, MAXAMOUNT))
#     613             if not chunk:
#     614                 raise IncompleteRead(b''.join(s), amt)
#
# ~/anaconda3/lib/python3.6/socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# ~/anaconda3/lib/python3.6/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1007                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1008                   self.__class__)
# -> 1009             return self.read(nbytes, buffer)
#    1010         else:
#    1011             return socket.recv_into(self, buffer, nbytes, flags)
#
# ~/anaconda3/lib/python3.6/ssl.py in read(self, len, buffer)
#     869             raise ValueError("Read on closed or unwrapped SSL socket.")
#     870         try:
# --> 871             return self._sslobj.read(len, buffer)
#     872         except SSLError as x:
#     873             if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# ~/anaconda3/lib/python3.6/ssl.py in read(self, len, buffer)
#     629         """
#     630         if buffer is not None:
# --> 631             v = self._sslobj.read(len, buffer)
#     632         else:
#     633             v = self._sslobj.read(len)
#
# KeyboardInterrupt:
